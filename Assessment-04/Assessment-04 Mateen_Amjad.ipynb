# %%
#Q4. Calculate the Sum of Digits of a Three-Digit Number

num = input("Enter three numbers: ")
sum = int(num[0]) + int(num[1]) + int(num[2])
print(sum)
# Out:
# Enter three numbers: 345
# 12

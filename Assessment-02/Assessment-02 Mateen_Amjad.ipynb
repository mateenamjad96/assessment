# %%
# Task-01: Printing a message
# Write a Python program that prints the following message "Hello, everyone! I am learning python. 😄" to the screen
print("Hello, everyone! I am learning python. 😄")
# Out:
# Hello, everyone! I am learning python. 😄

# %%
# Task 2: Declaring Variables
# Create a program that does the following: Declare variables to store: Your name (as a string),Your age (as an integer), and Your favorite animal (as a string).
name = "Mateen"
age = 20
favorite_animal = "lion"
print("Name:", name)
print("Age:", age)
print("Favorite Animal: ", favorite_animal)
# Out:
# Name: Mateen
# Age: 20
# Favorite Animal:  lion

# %%
# Task 3: Combining Variables in a Message
# Use the variables from Task 2 to create a single sentence and print it.
print(f'My name is {name}, I am {age} years old, and I love {favorite_animal}!')
# Out:
# My name is Mateen, I am 20 years old, and I love lion!

# %%
# Task 4: Playing with Different Data Types
favorite_movie = "Toy Story"
birth_year = 2001
price_of_snack = 20.5

print("Favorite Movie:", favorite_movie)
print("Birth Year:", birth_year)
print("Price of Snack:", price_of_snack)
# Out:
# Favorite Movie: Toy Story
# Birth Year: 2001
# Price of Snack: 20.5

# %%
# Task 5: Your Favorite Hobby
hobby = "reading books"
print(f"My favorite hobby is {hobby}")
# Out:
# My favorite hobby is reading books

# %%
# Extra Challenge -  adding two numbers using three variables
a = 3
b = 7
c = a + b
print("a = ", a)
print("b = ", b)
print("c = ", c, "(a & b combined!)")
# Out:
# a =  3
# b =  7
# c =  10 (a & b combined!)
